# %%
#Skiprows
import pandas as pd
i = pd.read_csv('D:\\data set\\student_results.csv', skiprows = 1)
i
# Out:
#    1001  10   2   9  3  5  50
# 0  1002  10   6   8  2  0  80
# 1  1003  10   3   8  2  4  60
# 2  1004  11   0  10  1  5  45
# 3  1005  11   4   7  2  0  75
# 4  1006  11  10   7  0  0  96
# 5  1007  12   4   6  0  0  80
# 6  1008  12  10   6  2  0  90
# 7  1009  12   2   8  2  4  60
# 8  1010  12   6   9  1  0  85

# %%
import pandas as pd
i = pd.read_csv('D:\\data set\\student_results.csv', skiprows = [1,2,3])
i
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1004     11          0            10                       1
# 1        1005     11          4             7                       2
# 2        1006     11         10             7                       0
# 3        1007     12          4             6                       0
# 4        1008     12         10             6                       2
# 5        1009     12          2             8                       2
# 6        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          45
# 1                 0          75
# 2                 0          96
# 3                 0          80
# 4                 0          90
# 5                 4          60
# 6                 0          85

# %%
import pandas as pd
i = pd.read_csv('D:\\data set\\student_results.csv', index_col = 'Student ID')
i
# Out:
#             Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Student ID
# 1001           10          2             9                       3
# 1002           10          6             8                       2
# 1003           10          3             8                       2
# 1004           11          0            10                       1
# 1005           11          4             7                       2
# 1006           11         10             7                       0
# 1007           12          4             6                       0
# 1008           12         10             6                       2
# 1009           12          2             8                       2
# 1010           12          6             9                       1
#
#             Mobile Games hrs  Percantege
# Student ID
# 1001                       5          50
# 1002                       0          80
# 1003                       4          60
# ...

# %%
import pandas as pd
i = pd.read_csv('D:\\data set\\student_results.csv', index_col = 0)
i
# Out:
#             Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Student ID
# 1001           10          2             9                       3
# 1002           10          6             8                       2
# 1003           10          3             8                       2
# 1004           11          0            10                       1
# 1005           11          4             7                       2
# 1006           11         10             7                       0
# 1007           12          4             6                       0
# 1008           12         10             6                       2
# 1009           12          2             8                       2
# 1010           12          6             9                       1
#
#             Mobile Games hrs  Percantege
# Student ID
# 1001                       5          50
# 1002                       0          80
# 1003                       4          60
# ...

# %%
import pandas as pd
i = pd.read_csv('D:\\data set\\student_results.csv', header=None)
i
# Out:
#              0      1          2             3                       4  \
# 0   Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs
# 1         1001     10          2             9                       3
# 2         1002     10          6             8                       2
# 3         1003     10          3             8                       2
# 4         1004     11          0            10                       1
# 5         1005     11          4             7                       2
# 6         1006     11         10             7                       0
# 7         1007     12          4             6                       0
# 8         1008     12         10             6                       2
# 9         1009     12          2             8                       2
# 10        1010     12          6             9                       1
#
#                    5           6
# 0   Mobile Games hrs  Percantege
# 1                  5          50
# ...

# %%
import pandas as pd
i = pd.read_csv('D:\\data set\\student_results.csv', names=[11,22,33,44,55,66,77])
i
# Out:
#             11     22         33            44                      55  \
# 0   Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs
# 1         1001     10          2             9                       3
# 2         1002     10          6             8                       2
# 3         1003     10          3             8                       2
# 4         1004     11          0            10                       1
# 5         1005     11          4             7                       2
# 6         1006     11         10             7                       0
# 7         1007     12          4             6                       0
# 8         1008     12         10             6                       2
# 9         1009     12          2             8                       2
# 10        1010     12          6             9                       1
#
#                   66          77
# 0   Mobile Games hrs  Percantege
# 1                  5          50
# ...
